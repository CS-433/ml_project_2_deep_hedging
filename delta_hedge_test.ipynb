# %%
import numpy as np
import pandas as pd
from src.env import StockTradingEnv

# %%
env = StockTradingEnv(True)

# %%
idx_ = 1000
S, C = env.asset_price[idx_], env.option_price[idx_]

# %%
S
# Out:
# array([100.        ,  99.15931619, 101.41724828, 101.75789482,
#        100.63571074, 100.38145682, 103.13651615, 104.49194417,
#        106.22388044, 108.98388368, 108.41566671, 109.30070583,
#        107.16295095, 111.31971438, 115.13709979, 116.38139742,
#        116.09941513, 116.90781466, 119.6383204 , 116.9288123 ,
#        117.26269577, 118.32923319, 119.53857836, 119.17970997,
#        119.58261313, 122.71459652, 122.27580994, 121.26595225,
#        121.19719637, 124.33286468, 125.55751108, 125.7759609 ,
#        124.293049  , 124.63171518, 124.39447115, 123.0095131 ,
#        123.8349806 , 124.52238953, 123.37121179, 123.47616682,
#        125.99872401, 125.48162261, 126.34416235, 124.2652872 ,
#        125.43238172, 125.52529631, 125.63813933, 126.03710179,
#        126.31164688, 122.99544652, 123.89057744, 124.51529205,
#        123.33217135, 121.4533573 , 125.33357907, 123.84751744,
#        123.92456573, 122.69681419, 123.27881114, 123.69175138])

# %%
C
# Out:
# array([56.14219739, 55.10405774, 56.47170292, 56.33929245, 55.06570321,
#        54.46242155, 56.17806519, 56.80401498, 57.71454752, 59.41930746,
#        58.52266462, 58.7497381 , 56.62754383, 59.37026674, 61.85737172,
#        62.32800613, 61.59453086, 61.70407273, 63.30698974, 60.64906439,
#        60.35855182, 60.62550063, 60.99168155, 60.12946097, 59.84642039,
#        61.66583673, 60.70188968, 59.28714377, 58.58850557, 60.34615643,
#        60.61537774, 60.08958274, 58.23687602, 57.77326066, 56.85088705,
#        55.03778621, 54.8909444 , 54.61840987, 52.92993892, 52.17252671,
#        53.22009131, 51.93933695, 51.6771687 , 49.16594344, 49.06952287,
#        48.13161133, 47.17211319, 46.38774075, 45.46611665, 41.81364782,
#        41.24629652, 40.41848181, 38.17190968, 35.33101551, 36.68714029,
#        33.90261338, 32.15822145, 29.21726952, 27.44627553, 25.3274326 ])

# %%
df_stock = pd.read_csv('data/Daily/asset_price_GBM_1_sim.csv')
df_optin = pd.read_csv('data/Daily/option_price_GBM_1_sim.csv')

# %%
df_stock
# Out:
#        1.000000000000000000e+02  9.782275404475404912e+01  \
# 0                         100.0                100.446454
# 1                         100.0                101.481353
# 2                         100.0                 99.693163
# 3                         100.0                101.261170
# 4                         100.0                100.664640
# ...                         ...                       ...
# 99994                     100.0                 98.433390
# 99995                     100.0                 99.670538
# 99996                     100.0                 97.554533
# 99997                     100.0                100.696980
# 99998                     100.0                100.668031
#
#        9.892978456257606013e+01  1.007187476938818094e+02  \
# 0                    101.645804                103.320387
# 1                    101.150343                 98.843894
# 2                     99.367351                100.435574
# ...

# %%
df_optin
# Out:
#        5.614219739190001235e+01  5.406710299783843965e+01  \
# 0                     56.142197                 56.105974
# 1                     56.142197                 56.913857
# 2                     56.142197                 55.519217
# 3                     56.142197                 56.741803
# 4                     56.142197                 56.276129
# ...                         ...                       ...
# 99994                 56.142197                 54.540418
# 99995                 56.142197                 55.501611
# 99996                 56.142197                 53.859435
# 99997                 56.142197                 56.301358
# 99998                 56.142197                 56.278774
#
#        5.453850604127703150e+01  5.553155614565073961e+01  \
# 0                     56.649933                 57.557752
# 1                     56.263694                 54.079611
# 2                     54.877692                 55.311810
# ...
